# %% [markdown]
# <img src='https://radiant-assets.s3-us-west-2.amazonaws.com/PrimaryRadiantMLHubLogo.png' alt='Radiant MLHub Logo' width='300'/>
#
# # How to use the Radiant MLHub API
#
# The Radiant MLHub API gives access to open Earth imagery training data for machine learning applications. You can learn more about the repository at the [Radiant MLHub site](https://mlhub.earth) and about the organization behind it at the [Radiant Earth Foundation site](https://radiant.earth).
#
# This Jupyter notebook, which you may copy and adapt for any use, shows basic examples of how to use the API. Full documentation for the API is available at [docs.mlhub.earth](docs.mlhub.earth).
#
# We'll show you how to set up your authorization, see the list of available collections and datasets, and retrieve the items (the data contained within them) from those collections.
#
# Each item in our collection is explained in json format compliant with [STAC](https://stacspec.org/) [label extension](https://github.com/radiantearth/stac-spec/tree/master/extensions/label) definition.

# %% [markdown]
# ## Dependencies
#
# This notebook utilizes the [`radiant-mlhub` Python client](https://pypi.org/project/radiant-mlhub/) for interacting with the API. If you are running this notebooks using Binder, then this dependency has already been installed. If you are running this notebook locally, you will need to install this yourself.
#
# See the official [`radiant-mlhub` docs](https://radiant-mlhub.readthedocs.io/) for more documentation of the full functionality of that library.

# %% [markdown]
# ## Authentication
#
# ### Create an API Key
#
# Access to the Radiant MLHub API requires an API key. To get your API key, go to [https://mlhub.earth/profile](https://mlhub.earth/profile). If you have not used Radiant MLHub before, you will need to sign up and create a new account. Otherwise, sign in. In the **API Keys** tab, you'll be able to create API key(s), which you will need. *Do not share* your API key with others: your usage may be limited and sharing your API key is a security risk.
#
# ### Configure the Client
#
# Once you have your API key, you need to configure the `radiant_mlhub` library to use that key. There are a number of ways to configure this (see the [Authentication docs](https://radiant-mlhub.readthedocs.io/en/latest/authentication.html) for details).
#
# For these examples, we will set the `MLHUB_API_KEY` environment variable. Run the cell below to save your API key as an environment variable that the client library will recognize.
#
# *If you are running this notebook locally and have configured a profile as described in the [Authentication docs](https://radiant-mlhub.readthedocs.io/en/latest/authentication.html), then you do not need to execute this cell.*

# %%
import os

os.environ['MLHUB_API_KEY'] = 'd5fe86bf9abf5fef7e1513923b66ee5016768bc55775ccd1abf25c9326e1c8ec'#'PASTE_YOUR_API_KEY_HERE'

# %%
from radiant_mlhub import client, get_session

# %% [markdown]
# ## List data collections
#
# A **collection** in the Radiant MLHub API is a [STAC Collection](https://github.com/radiantearth/stac-spec/tree/master/collection-spec) representing a group of resources (represented as [STAC Items](https://github.com/radiantearth/stac-spec/tree/master/item-spec) and their associated assets) covering a given spatial and temporal extent. A Radiant MLHub collection may contain resources representing training labels, source imagery, or (rarely) both.
#
# Use the `client.list_collections` function to list all available collections and view their properties. The following cell uses the `client.list_collections` function to print the ID, license (if available), and citation (if available) for all available collections.

# %%
collections = client.list_collections()
for c in collections:
    collection_id = c['id']
    license = c.get('license', 'N/A')
    citation = c.get('sci:citation', 'N/A')

    print(f'ID:       {collection_id}\nLicense:  {license}\nCitation: {citation}\n')
# Out:
# ID:       ramp_sylhet_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Sylhet, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.fnv87x
#
# ID:       ramp_sylhet_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Sylhet, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.fnv87x
#
# ID:       ref_landcovernet_sa_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) "LandCoverNet South America: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.6a27yv
#
# ID:       ramp_wa_ghana_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Wa, Ghana, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.6l9q5d
#
# ID:       lacuna_fund_eotg_v1_labels
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       ref_landcovernet_sa_v1_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) "LandCoverNet South America: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.6a27yv
#
# ID:       dlr_fusion_competition_germany_train_labels
# License:  DL-DE->BY-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       ref_african_crops_kenya_02_labels
# License:  CC-BY-SA-4.0
# Citation: Radiant Earth Foundation (2020) "CV4A Competition Kenya Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.DW605X
#
# ID:       ref_landcovernet_af_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Alemohammad S.H., Ballantyne A., Bromberg Gaber Y., Booth K., Nakanuku-Diggs L., & Miglarese A.H. (2020) "LandCoverNet Africa: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.d2ce8i
#
# ID:       ref_landcovernet_af_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: Alemohammad S.H., Ballantyne A., Bromberg Gaber Y., Booth K., Nakanuku-Diggs L., & Miglarese A.H. (2020) "LandCoverNet Africa: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.d2ce8i
#
# ID:       ramp_mesopotamia_st_vincent_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Mesopotamia, St. Vincent, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.yhk0md
#
# ID:       ref_south_africa_crops_competition_v1_train_labels
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       ref_south_africa_crops_competition_v1_train_source_s1
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       ref_south_africa_crops_competition_v1_train_source_s2
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       ref_landcovernet_na_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet North America: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.jx15e8
#
# ID:       ref_african_crops_kenya_01_source
# License:  CC-BY-SA-4.0
# Citation: PlantVillage (2019) "PlantVillage Kenya Ground Reference Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.U41J87
#
# ID:       c2smsfloods_v1_source_s1
# License:  CC-BY-4.0
# Citation: Cloud to Street, Microsoft, Radiant Earth Foundation. (2022). A global flood events and cloud cover dataset (Version 1.0).[Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.oz32gz
#
# ID:       ramp_paris_france_labels
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Paris, France, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.t86thc
#
# ID:       bigearthnet_v1_source
# License:  CDLA-Permissive-1.0
# Citation: G. Sumbul, M. Charfuelan, B. Demir, V. Markl, "BigEarthNet: A Large-Scale Benchmark Archive for Remote Sensing Image Understanding", IEEE International Geoscience and Remote Sensing Symposium, pp. 5901-5904, Yokohama, Japan, 2019.
#
# ID:       cgiar_east_africa_agricultural_field_centers_labels
# License:  CC-BY-NC-4.0
# Citation: Amer, Karim; Eissa, Kareem (2021): GPS Coordinates of 18,482 Crop Fields in East Africa with Improved Accuracy using Planet Imagery and Yolo v5 Object Detection Model. figshare. Dataset. https://doi.org/10.6084/m9.figshare.15157263.v1
#
# ID:       cgiar_east_africa_agricultural_field_centers_source_planet
# License:  CC-BY-NC-4.0
# Citation: Amer, Karim; Eissa, Kareem (2021): GPS Coordinates of 18,482 Crop Fields in East Africa with Improved Accuracy using Planet Imagery and Yolo v5 Object Detection Model. figshare. Dataset. https://doi.org/10.6084/m9.figshare.15157263.v1
#
# ID:       ramp_paris_france_source
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Paris, France, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.t86thc
#
# ID:       ramp_ndjamena_chad_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - N'Djamena, Chad, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.b0noju
#
# ID:       marida_v1_raster_labels
# License:  CC-BY-4.0
# Citation: Kikaki K, Kakogeorgiou I, Mikeli P, Raitsos DE, Karantzalos K (2022) MARIDA: A benchmark for Marine Debris detection from Sentinel-2 remote sensing data. PLoS ONE 17(1): e0262247. https://doi.org/10.1371/journal.pone.0262247
#
# ID:       sn7_train_labels
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       microsoft_chesapeake_landsat_leaf_off
# License:  CC-PDDC
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       idiv_asia_crop_type_labels
# License:  CC-BY-4.0
# Citation: Remelgado, Ruben; Zaitov, Sherzod; Kenjabaev, Shavkat; Stulina, Galina; Sultanov, Murod; Ibrakhimov, Mirzakhayot; et al. (2020): A crop type dataset for consistent land cover classification in Central Asia. figshare. Dataset. https://doi.org/10.6084/m9.figshare.12047478.v2
#
# ID:       rti_rwanda_crop_type_source
# License:  CC-BY-NC-SA-4.0
# Citation: Rineer J., Beach R., Lapidus D., O’Neil M., Temple D., Ujeneza N., Cajka J., & Chew R. (2021) “Drone Imagery Classification Training Dataset for Crop Types in Rwanda”, Version 1.0, Radiant MLHub https://doi.org/10.34911/rdnt.r4p1fr
#
# ID:       marida_v1_source
# License:  CC-BY-4.0
# Citation: Kikaki K, Kakogeorgiou I, Mikeli P, Raitsos DE, Karantzalos K (2022) MARIDA: A benchmark for Marine Debris detection from Sentinel-2 remote sensing data. PLoS ONE 17(1): e0262247. https://doi.org/10.1371/journal.pone.0262247
#
# ID:       marida_v1_vector_labels
# License:  CC-BY-4.0
# Citation: Kikaki K, Kakogeorgiou I, Mikeli P, Raitsos DE, Karantzalos K (2022) MARIDA: A benchmark for Marine Debris detection from Sentinel-2 remote sensing data. PLoS ONE 17(1): e0262247. https://doi.org/10.1371/journal.pone.0262247
#
# ID:       microsoft_chesapeake_buildings
# License:  CDLA-Permissive-1.0
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       microsoft_chesapeake_nlcd
# License:  CDLA-Permissive-1.0
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       ref_african_crops_tanzania_01_labels
# License:  CC-BY-SA-4.0
# Citation: Great African Food Company (2019) "Great African Food Company Tanzania Ground Reference Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.5VX40R
#
# ID:       nasa_marine_debris_source
# License:  CC-BY-NC-4.0
# Citation: Shah, A., Thomas, L., & Maskey, M. (2021) "Marine Debris Dataset for Object Detection in Planetscope Imagery", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9r6ekg
#
# ID:       nasa_tropical_storm_competition_test_labels
# License:  CC-BY-4.0
# Citation: M. Maskey, R. Ramachandran, I. Gurung, B. Freitag, M. Ramasubramanian, J. Miller"Tropical Cyclone Wind Estimation Competition Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.xs53up
#
# ID:       sn2_AOI_5_Khartoum
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       nasa_tropical_storm_competition_test_source
# License:  CC-BY-4.0
# Citation: M. Maskey, R. Ramachandran, I. Gurung, B. Freitag, M. Ramasubramanian, J. Miller"Tropical Cyclone Wind Estimation Competition Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.xs53up
#
# ID:       nasa_tropical_storm_competition_train_labels
# License:  CC-BY-4.0
# Citation: M. Maskey, R. Ramachandran, I. Gurung, B. Freitag, M. Ramasubramanian, J. Miller"Tropical Cyclone Wind Estimation Competition Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.xs53up
#
# ID:       nasa_tropical_storm_competition_train_source
# License:  CC-BY-4.0
# Citation: M. Maskey, R. Ramachandran, I. Gurung, B. Freitag, M. Ramasubramanian, J. Miller"Tropical Cyclone Wind Estimation Competition Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.xs53up
#
# ID:       open_cities_ai_challenge_train_tier_1_labels
# License:  ODbL-1.0
# Citation: GFDRR Labs (2020). "Open Cities AI Challenge Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.f94cxb
#
# ID:       open_cities_ai_challenge_train_tier_1_source
# License:  CC-BY-4.0
# Citation: GFDRR Labs (2020). "Open Cities AI Challenge Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.f94cxb
#
# ID:       open_cities_ai_challenge_train_tier_2_labels
# License:  ODbL-1.0
# Citation: GFDRR Labs (2020). "Open Cities AI Challenge Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.f94cxb
#
# ID:       open_cities_ai_challenge_train_tier_2_source
# License:  CC-BY-4.0
# Citation: GFDRR Labs (2020). "Open Cities AI Challenge Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.f94cxb
#
# ID:       ref_african_crops_kenya_01_labels
# License:  CC-BY-SA-4.0
# Citation: PlantVillage (2019) "PlantVillage Kenya Ground Reference Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.U41J87
#
# ID:       ramp_nairobi_kenya_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Nairobi, Kenya, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.ldarow
#
# ID:       ref_african_crops_uganda_01_labels
# License:  CC-BY-SA-4.0
# Citation: Bocquet, C., & Dalberg Data Insights. (2019) "Dalberg Data Insights Uganda Crop Classification", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.EII04X
#
# ID:       ref_cloud_cover_detection_challenge_v1_test_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation. (2022). Sentinel-2 Cloud Cover Segmentation Dataset (Version 1). Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.hfq6m7
#
# ID:       ref_cloud_cover_detection_challenge_v1_test_source
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation. (2022). Sentinel-2 Cloud Cover Segmentation Dataset (Version 1). Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.hfq6m7
#
# ID:       ref_cloud_cover_detection_challenge_v1_train_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation. (2022). Sentinel-2 Cloud Cover Segmentation Dataset (Version 1) [Data set]. Radiant MLHub. https://doi.org/10.34911/RDNT.HFQ6M7
#
# ID:       ref_cloud_cover_detection_challenge_v1_train_source
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation. (2022). Sentinel-2 Cloud Cover Segmentation Dataset (Version 1). Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.hfq6m7
#
# ID:       ramp_les_cayes_haiti_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Les Cayes, Haiti, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.lkskd8
#
# ID:       sn7_train_source
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       ref_landcovernet_sa_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) "LandCoverNet South America: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.6a27yv
#
# ID:       c2smsfloods_v1_labels_s2_water
# License:  CC-BY-4.0
# Citation: Cloud to Street, Microsoft, Radiant Earth Foundation. (2022). A global flood events and cloud cover dataset (Version 1.0).[Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.oz32gz
#
# ID:       ref_landcovernet_af_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Alemohammad S.H., Ballantyne A., Bromberg Gaber Y., Booth K., Nakanuku-Diggs L., & Miglarese A.H. (2020) "LandCoverNet: A Global Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.d2ce8i
#
# ID:       ref_fusion_competition_south_africa_train_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       microsoft_chesapeake_landsat_leaf_on
# License:  CC-PDDC
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       ref_african_crops_uganda_01_source
# License:  CC-BY-SA-4.0
# Citation: Bocquet, C., & Dalberg Data Insights. (2019) "Dalberg Data Insights Uganda Crop Classification", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.EII04X
#
# ID:       ref_south_africa_crops_competition_v1_test_labels
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       sen12ts_v1_source_sentinel_1
# License:  CC-BY-NC-4.0
# Citation: Conlon, T. & Rustowicz, R. (2022), SEN12TS, Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9qh1mb
#
# ID:       ref_landcovernet_sa_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) "LandCoverNet South America: A Geographically Diverse Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.6a27yv
#
# ID:       ref_landcovernet_na_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet North America: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.jx15e8
#
# ID:       ref_landcovernet_na_v1_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet North America: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.jx15e8
#
# ID:       ref_african_crops_tanzania_01_source
# License:  CC-BY-SA-4.0
# Citation: Great African Food Company (2019) "Great African Food Company Tanzania Ground Reference Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.5VX40R
#
# ID:       ref_landcovernet_eu_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: ['Radiant Earth Foundation (2022) LandCoverNet Europe: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.7s12zu']
#
# ID:       c2smsfloods_v1_source_s2
# License:  CC-BY-4.0
# Citation: Cloud to Street, Microsoft, Radiant Earth Foundation. (2022). A global flood events and cloud cover dataset (Version 1.0).[Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.oz32gz
#
# ID:       ref_landcovernet_na_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet North America: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.jx15e8
#
# ID:       ref_south_africa_crops_competition_v1_test_source_s1
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       sn2_AOI_4_Shanghai
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       c2smsfloods_v1_labels_s2_cloud
# License:  CC-BY-4.0
# Citation: Cloud to Street, Microsoft, Radiant Earth Foundation. (2022). A global flood events and cloud cover dataset (Version 1.0).[Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.oz32gz
#
# ID:       ref_landcovernet_eu_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: ['Radiant Earth Foundation (2022) LandCoverNet Europe: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.7s12zu']
#
# ID:       ramp_mesopotamia_st_vincent_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Mesopotamia, St. Vincent, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.yhk0md
#
# ID:       sen12ts_v1_labels_usda
# License:  CC-BY-NC-4.0
# Citation: Conlon, T. & Rustowicz, R. (2022), SEN12TS, Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9qh1mb
#
# ID:       sen12ts_v1_labels_sigpac
# License:  CC-BY-NC-4.0
# Citation: Conlon, T. & Rustowicz, R. (2022), SEN12TS, Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9qh1mb
#
# ID:       model_ramp_baseline_v1
# License:  CC-BY-NC-4.0
# Citation: N/A
#
# ID:       dlr_fusion_competition_germany_train_source_planet
# License:  CC-BY-SA-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       dlr_fusion_competition_germany_train_source_planet_5day
# License:  CC-BY-SA-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       ref_landcovernet_au_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Australia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.0vgi25
#
# ID:       ramp_chittagong_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Chittagong, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.zp22dh
#
# ID:       ramp_muscat_oman_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Muscat, Oman, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.ddqkh5
#
# ID:       microsoft_chesapeake_lc
# License:  CDLA-Permissive-1.0
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       ref_landcovernet_au_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Australia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.0vgi25
#
# ID:       rti_rwanda_crop_type_labels
# License:  CC-BY-NC-SA-4.0
# Citation: Rineer J., Beach R., Lapidus D., O’Neil M., Temple D., Ujeneza N., Cajka J., & Chew R. (2021) “Drone Imagery Classification Training Dataset for Crop Types in Rwanda”, Version 1.0, Radiant MLHub https://doi.org/10.34911/rdnt.r4p1fr
#
# ID:       lacuna_fund_eotg_v1_source_perspective
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       bigearthnet_v1_labels
# License:  CDLA-Permissive-1.0
# Citation: G. Sumbul, M. Charfuelan, B. Demir, V. Markl, "BigEarthNet: A Large-Scale Benchmark Archive for Remote Sensing Image Understanding", IEEE International Geoscience and Remote Sensing Symposium, pp. 5901-5904, Yokohama, Japan, 2019.
#
# ID:       ref_landcovernet_au_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Australia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.0vgi25
#
# ID:       ref_landcovernet_au_v1_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Australia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.0vgi25
#
# ID:       dlr_fusion_competition_germany_train_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       dlr_fusion_competition_germany_test_source_planet_5day
# License:  CC-BY-SA-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       sen12ts_v1_labels_esa
# License:  CC-BY-NC-4.0
# Citation: Conlon, T. & Rustowicz, R. (2022), SEN12TS, Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9qh1mb
#
# ID:       ref_landcovernet_af_v1_labels
# License:  CC-BY-4.0
# Citation: Alemohammad S.H., Ballantyne A., Bromberg Gaber Y., Booth K., Nakanuku-Diggs L., & Miglarese A.H. (2020) "LandCoverNet: A Global Land Cover Classification Training Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.d2ce8i
#
# ID:       ref_landcovernet_eu_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: ['Radiant Earth Foundation (2022) LandCoverNet Europe: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.7s12zu']
#
# ID:       ref_landcovernet_eu_v1_labels
# License:  CC-BY-4.0
# Citation: ['Radiant Earth Foundation (2022) LandCoverNet Europe: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.7s12zu']
#
# ID:       ref_landcovernet_as_v1_labels
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Asia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.63fxe5
#
# ID:       ramp_nairobi_kenya_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Nairobi, Kenya, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.ldarow
#
# ID:       ref_landcovernet_as_v1_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Asia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.63fxe5
#
# ID:       ref_landcovernet_as_v1_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Asia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.63fxe5
#
# ID:       microsoft_chesapeake_naip
# License:  CC-PDDC
# Citation: Robinson C, Hou L, Malkin K, Soobitsky R, Czawlytko J, Dilkina B, Jojic N. Large Scale High-Resolution Land Cover Mapping with Multi-Resolution Data. Proceedings of the 2019 Conference on Computer Vision and Pattern Recognition (CVPR 2019).
#
# ID:       open_cities_ai_challenge_test
# License:  CC-BY-4.0
# Citation: GFDRR Labs (2020). "Open Cities AI Challenge Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.f94cxb
#
# ID:       ref_landcovernet_as_v1_source_landsat_8
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation (2022) LandCoverNet Asia: A Geographically Diverse Land Cover Classification Training Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.63fxe5
#
# ID:       ramp_barishal_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Barishal, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.cmejc0
#
# ID:       dlr_fusion_competition_germany_test_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       dlr_fusion_competition_germany_test_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       sn2_AOI_3_Paris
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       ramp_bentiu_south_sudan_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Bentiu, South Sudan, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wnuc7e
#
# ID:       ramp_ndjamena_chad_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - N'Djamena, Chad, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.b0noju
#
# ID:       dlr_fusion_competition_germany_train_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       ref_south_africa_crops_competition_v1_test_source_s2
# License:  CC-BY-4.0
# Citation: Western Cape Department of Agriculture, Radiant Earth Foundation (2021) "Crop Type Classification Dataset for Western Cape, South Africa", Version 1.0, Radiant MLHub, [Date Accessed] https://doi.org/10.34911/rdnt.j0co8q
#
# ID:       ref_fusion_competition_south_africa_train_source_planet
# License:  CC-BY-SA-2.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       sen12ts_v1_source_sentinel_2
# License:  CC-BY-NC-4.0
# Citation: Conlon, T. & Rustowicz, R. (2022), SEN12TS, Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9qh1mb
#
# ID:       lacuna_fund_eotg_v1_source_sentinel
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       lacuna_fund_eotg_v1_source_arc
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       c2smsfloods_v1_labels_s1_water
# License:  CC-BY-4.0
# Citation: Cloud to Street, Microsoft, Radiant Earth Foundation. (2022). A global flood events and cloud cover dataset (Version 1.0).[Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.oz32gz
#
# ID:       ramp_lubumbashi_drc_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Lubumbashi, Democratic Republic of the Congo, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wmflve
#
# ID:       ramp_lubumbashi_drc_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Lubumbashi, Democratic Republic of the Congo, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wmflve
#
# ID:       model-cv4a-crop-detection-v1
# License:  CC-BY-4.0
# Citation: N/A
#
# ID:       model-cyclone-wind-estimation-torchgeo
# License:  MIT
# Citation: N/A
#
# ID:       nasa_marine_debris_labels
# License:  CC-BY-NC-4.0
# Citation: Shah, A., Thomas, L., & Maskey, M. (2021) "Marine Debris Dataset for Object Detection in Planetscope Imagery", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9r6ekg
#
# ID:       ramp_muscat_oman_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Muscat, Oman, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.ddqkh5
#
# ID:       ramp_chittagong_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Chittagong, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.zp22dh
#
# ID:       lacuna_fund_eotg_v1_source_era5
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       rti_rwanda_crop_type_raw
# License:  CC-BY-NC-SA-4.0
# Citation: Rineer J., Beach R., Lapidus D., O’Neil M., Temple D., Ujeneza N., Cajka J., & Chew R. (2021) “Drone Imagery Classification Training Dataset for Crop Types in Rwanda”, Version 1.0, Radiant MLHub https://doi.org/10.34911/rdnt.r4p1fr
#
# ID:       sen12floods_s1_labels
# License:  CC-BY-4.0
# Citation: Clément Rambour, Nicolas Audebert, Elise Koeniguer, Bertrand Le Saux, Michel Crucianu, Mihai Datcu, September 14, 2020, "SEN12-FLOOD : a SAR and Multispectral Dataset for Flood Detection ", IEEE Dataport, doi: https://dx.doi.org/10.21227/w6xz-s898.
#
# ID:       sen12floods_s1_source
# License:  CC-BY-4.0
# Citation: Clément Rambour, Nicolas Audebert, Elise Koeniguer, Bertrand Le Saux, Michel Crucianu, Mihai Datcu, September 14, 2020, "SEN12-FLOOD : a SAR and Multispectral Dataset for Flood Detection ", IEEE Dataport, doi: https://dx.doi.org/10.21227/w6xz-s898.
#
# ID:       sen12floods_s2_labels
# License:  CC-BY-4.0
# Citation: Clément Rambour, Nicolas Audebert, Elise Koeniguer, Bertrand Le Saux, Michel Crucianu, Mihai Datcu, September 14, 2020, "SEN12-FLOOD : a SAR and Multispectral Dataset for Flood Detection ", IEEE Dataport, doi: https://dx.doi.org/10.21227/w6xz-s898.
#
# ID:       sen12floods_s2_source
# License:  CC-BY-4.0
# Citation: Clément Rambour, Nicolas Audebert, Elise Koeniguer, Bertrand Le Saux, Michel Crucianu, Mihai Datcu, September 14, 2020, "SEN12-FLOOD : a SAR and Multispectral Dataset for Flood Detection ", IEEE Dataport, doi: https://dx.doi.org/10.21227/w6xz-s898.
#
# ID:       sn1_AOI_1_RIO
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn2_AOI_2_Vegas
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn3_AOI_2_Vegas
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn3_AOI_3_Paris
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn3_AOI_4_Shanghai
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn3_AOI_5_Khartoum
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn4_AOI_6_Atlanta
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn5_AOI_7_Moscow
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn5_AOI_8_Mumbai
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn6_AOI_11_Rotterdam
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       sn7_test_source
# License:  CC-BY-SA-4.0
# Citation: N/A
#
# ID:       su_african_crops_ghana_labels
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in Ghana Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.ry138p
#
# ID:       su_african_crops_ghana_source_planet
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in Ghana Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.ry138p
#
# ID:       su_african_crops_ghana_source_s1
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in Ghana Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.ry138p
#
# ID:       su_african_crops_ghana_source_s2
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in Ghana Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.ry138p
#
# ID:       su_african_crops_south_sudan_labels
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in South Sudan Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.v6kx6n
#
# ID:       su_african_crops_south_sudan_source_planet
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in South Sudan Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.v6kx6n
#
# ID:       su_african_crops_south_sudan_source_s1
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in South Sudan Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.v6kx6n
#
# ID:       su_african_crops_south_sudan_source_s2
# License:  CC-BY-SA-4.0
# Citation: Rustowicz R., Cheong R., Wang L., Ermon S., Burke M., Lobell D. (2020) "Semantic Segmentation of Crop Type in South Sudan Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.v6kx6n
#
# ID:       su_sar_moisture_content
# License:  CC-BY-NC-ND-4.0
# Citation: Rao, K., Williams, A.P., Fortin, J. & Konings, A.G. (2020). SAR-enhanced mapping of live fuel moisture content. Remote Sens. Environ., 245.
#
# ID:       ts_cashew_benin_labels
# License:  CC-BY-4.0
# Citation: Jin Z., Lin C., Weigl C., Obarowski J., & Hale, D. (2021) “Smallholder Cashew Plantations in Benin” Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.hfv20i
#
# ID:       ts_cashew_benin_source
# License:  CC-BY-4.0
# Citation: Jin Z., Lin C., Weigl C., Obarowski J., & Hale, D. (2021) “Smallholder Cashew Plantations in Benin” Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.hfv20i
#
# ID:       umd_mali_crop_type_labels
# License:  CC-BY-4.0
# Citation: Nakalembe, C.L., Ouedraogo, H., Diarra, N., & Kuzimbu, B. (2021). 2019 Mali Crop Type Training Data for Machine Learning (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.tgz68o
#
# ID:       umd_mali_crop_type_source
# License:  CC-BY-4.0
# Citation: Nakalembe, C.L., Ouedraogo, H., Diarra, N., & Kuzimbu, B. (2021). 2019 Mali Crop Type Training Data for Machine Learning (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.tgz68o
#
# ID:       lacuna_fund_eotg_v1_source_tamsat
# License:  CC-BY-SA-4.0
# Citation: Waithaka, L., Kramer, B., Hufkens, K., Kivuva, B., & Mansabdar, S. (2022) Eyes on the Ground Image Data, Version 1.0, (Version 1.0) Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.1bs2jw
#
# ID:       ref_agrifieldnet_competition_v1_source
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation & IDinsight (2022) AgriFieldNet Competition Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.wu92p1
#
# ID:       ref_agrifieldnet_competition_v1_labels_train
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation & IDinsight (2022) AgriFieldNet Competition Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.wu92p1
#
# ID:       nasa_rwanda_field_boundary_competition_labels_train
# License:  CC-BY-4.0
# Citation: NASA Harvest, Radiant Earth Foundation, & TaQadam. (2022). Rwanda Field Boundary Competition Dataset (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/RDNT.G580WW
#
# ID:       ramp_barishal_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Barishal, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.cmejc0
#
# ID:       ramp_hpa_an_myanmar_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Hpa-an, Myanmar, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.rhevr7
#
# ID:       ramp_bentiu_south_sudan_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Bentiu, South Sudan, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wnuc7e
#
# ID:       ramp_daressalaam_tanzania_labels
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Dar es Salaam, Tanzania, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.895jh7
#
# ID:       ref_agrifieldnet_competition_v1_labels_test
# License:  CC-BY-4.0
# Citation: Radiant Earth Foundation & IDinsight (2022) AgriFieldNet Competition Dataset, Version 1.0, Radiant MLHub. https://doi.org/10.34911/rdnt.wu92p1
#
# ID:       nasa_rwanda_field_boundary_competition_source_train
# License:  proprietary
# Citation: NASA Harvest, Radiant Earth Foundation, & TaQadam. (2022). Rwanda Field Boundary Competition Dataset (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/RDNT.G580WW
#
# ID:       dlr_fusion_competition_germany_test_source_planet
# License:  CC-BY-SA-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       ramp_daressalaam_tanzania_source
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Dar es Salaam, Tanzania, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.895jh7
#
# ID:       nasa_rwanda_field_boundary_competition_source_test
# License:  proprietary
# Citation: NASA Harvest, Radiant Earth Foundation, & TaQadam. (2022). Rwanda Field Boundary Competition Dataset (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/RDNT.G580WW
#
# ID:       ramp_mzuzu_malawi_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Mzuzu, Malawi, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.824213
#
# ID:       ramp_shanghai_china_labels
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Shanghai, China, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.grvh9e
#
# ID:       ramp_accra_ghana_labels
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Accra, Ghana, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.zyiv7t
#
# ID:       ramp_dhaka_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Dhaka, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.848og9
#
# ID:       ramp_les_cayes_haiti_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Les Cayes, Haiti, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.lkskd8
#
# ID:       ramp_manjama_sierra_leone_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Manjama, Sierra Leone, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.fp33ih
#
# ID:       dlr_fusion_competition_germany_test_labels
# License:  DL-DE->BY-2.0
# Citation: Planet, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Brandenburg, Germany (Version 1.0) [Data set]. Radiant MLHub. https://doi.org/10.34911/rdnt.z9y7vu
#
# ID:       ramp_accra_ghana_source
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Accra, Ghana, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.zyiv7t
#
# ID:       model_ecaas_agrifieldnet_gold_v1
# License:  CC-BY-4.0
# Citation: N/A
#
# ID:       ref_fusion_competition_south_africa_train_source_planet_5day
# License:  CC-BY-SA-2.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_train_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_test_source_planet
# License:  CC-BY-SA-2.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_train_labels
# License:  CC-BY-NC-SA-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ramp_hpa_an_myanmar_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Hpa-an, Myanmar, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.rhevr7
#
# ID:       ramp_coxs_bazar_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Cox's Bazar, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.xrlqp1
#
# ID:       ref_fusion_competition_south_africa_test_source_planet_5day
# License:  CC-BY-SA-2.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_test_source_sentinel_1
# License:  CC-BY-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_test_source_sentinel_2
# License:  CC-BY-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       ref_fusion_competition_south_africa_test_labels
# License:  CC-BY-NC-SA-4.0
# Citation: Planet, Radiant Earth Foundation, Western Cape Department of Agriculture, & German Aerospace Center (DLR). (2021). A Fusion Dataset for Crop Type Classification in Western Cape, South Africa (Version 1.0) [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.gqy868
#
# ID:       csu_synthetic_attribution_data
# License:  CC-BY-4.0
# Citation: Mamalakis, A., Ebert-Uphoff, I., Barnes, E. A. (2022) Neural Network Attribution Methods for Problems in Geoscience: A Novel Synthetic Benchmark Dataset, Environmental Data Science, DOI: 10.1017/eds.2022.7
#
# ID:       ramp_jashore_bangladesh_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Jashore, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wn4jmp
#
# ID:       ramp_wa_ghana_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Wa, Ghana, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.6l9q5d
#
# ID:       ramp_jashore_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Jashore, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.wn4jmp
#
# ID:       ref_african_crops_kenya_02_source
# License:  CC-BY-SA-4.0
# Citation: Radiant Earth Foundation (2020) "CV4A Competition Kenya Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.DW605X
#
# ID:       nasa_floods_v1_source
# License:  CC-BY-4.0
# Citation: Gahlot, S., Gurung, I., Molthan, A., & Maskey, M. (2021) "Flood Extent Data for Machine Learning", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9r6ekg
#
# ID:       nasa_floods_v1_labels
# License:  CC-BY-4.0
# Citation: Gahlot, S., Gurung, I., Molthan, A., & Maskey, M. (2021) "Flood Extent Data for Machine Learning", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/rdnt.9r6ekg
#
# ID:       ramp_dhaka_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Dhaka, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.848og9
#
# ID:       ramp_coxs_bazar_bangladesh_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Cox's Bazar, Bangladesh, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.xrlqp1
#
# ID:       ramp_shanghai_china_source
# License:  CC-BY-SA-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Shanghai, China, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.grvh9e
#
# ID:       ramp_mzuzu_malawi_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Mzuzu, Malawi, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.824213
#
# ID:       ramp_manjama_sierra_leone_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Manjama, Sierra Leone, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.fp33ih
#
# ID:       ramp_karnataka_india_labels
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Karnataka, India, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.5y2w17
#
# ID:       ramp_karnataka_india_source
# License:  CC-BY-NC-4.0
# Citation: DevGlobal, (2022). ramp Building Footprint Training Dataset - Karnataka, India, Version 1.0, [Date Accessed]. Radiant MLHub. https://doi.org/10.34911/rdnt.5y2w17
#
# ID:       model_ecaas_agrifieldnet_silver_v1
# License:  CC-BY-4.0
# Citation: N/A

# %% [markdown]
# Collection objects have many other properties besides the ones shown above. The cell below prints the `ref_african_crops_kenya_01_labels` collection object in its entirety.

# %%
kenya_crops_labels = next(c for c in collections if c['id'] == 'ref_african_crops_kenya_01_labels')
kenya_crops_labels
# Out:
# {'id': 'ref_african_crops_kenya_01_labels',
#  'type': 'Collection',
#  'links': [{'rel': 'items',
#    'type': 'application/geo+json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_labels/items'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/'},
#   {'rel': 'self',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_labels'}],
#  'assets': {'documentation': {'href': 'https://radiantearth.blob.core.windows.net/mlhub/african-crops-01/Kenya_Documentation.pdf',
#    'type': 'application/pdf',
#    'title': 'Dataset Documentation'},
#   'property_descriptions': {'href': 'https://radiantearth.blob.core.windows.net/mlhub/african-crops-01/Kenya_properties.csv',
#    'type': 'text/csv',
#    'title': 'Label Property Descriptions'}},
#  'extent': {'spatial': {'bbox': [[34.18191992149459,
#      0.4724181558451209,
#      34.3714943155646,
#      0.7144217206851109]]},
#   'temporal': {'interval': [['2018-04-10T00:00:00Z',
#      '2020-03-13T00:00:00Z']]}},
#  'license': 'CC-BY-SA-4.0',
#  'sci:doi': '10.34911/rdnt.u41j87',
#  'providers': [{'url': 'https://radiant.earth',
#    'name': 'Radiant Earth Foundation',
#    'roles': ['licensor', 'host', 'processor']}],
#  'summaries': {'label:type': ['vector'],
#   'label:tasks': ['classification'],
#   'label:classes': [{'name': 'Water Resource', 'classes': ['rainfed']},
#    {'name': 'Crop1',
#     'classes': ['Sorghum',
#      'Millet',
#      'Soybean',
#      'Fallowland',
#      'Cassava',
#      'Sweetpotato',
#      'Bean',
#      'Cabbage',
#      'Tomato',
#      'Maize',
#      'Groundnut',
#      'Banana',
#      'Sugarcane']},
#    {'name': 'Crop2',
#     'classes': ['',
#      'Soybean',
#      'Millet',
#      'Fallowland',
#      'Cassava',
#      'Sweetpotato',
#      'Bean',
#      'Sorghum',
#      'Groundnut',
#      'Maize',
#      'Cowpea']},
#    {'name': 'Crop3',
#     'classes': ['', 'Soybean', 'Millet', 'Cassava', 'Bean', 'Groundnut']},
#    {'name': 'Crop4',
#     'classes': ['',
#      'Soybean',
#      'Millet',
#      'Sweetpotato',
#      'Groundnut',
#      'Tomato',
#      'Bean']},
#    {'name': 'Crop5', 'classes': ['', 'Bean']},
#    {'name': 'Variety',
#     'classes': ['Duma 48',
#      'WS 507, Duma',
#      'Local',
#      'Hybrid 513',
#      'WS 513, DH 04',
#      'DK, WS 505',
#      'WS 403, WS 513',
#      'MM 04',
#      'WS 507',
#      'DK 777',
#      'WS 513',
#      'WS 516',
#      'Null',
#      'Gabon',
#      'Duma',
#      'DH 04',
#      'Magana',
#      'WS 505',
#      'WS 509',
#      'WS 505, WS 513',
#      'Tanzania',
#      'DK',
#      'WS 403',
#      'DK 4380',
#      'WS 505, Duma 403',
#      'WS 505, WS 507']}],
#   'label:methods': ['manual']},
#  'description': 'African Crops Kenya',
#  'sci:citation': 'PlantVillage (2019) "PlantVillage Kenya Ground Reference Crop Type Dataset", Version 1.0, Radiant MLHub. [Date Accessed] https://doi.org/10.34911/RDNT.U41J87',
#  'stac_version': '1.0.0',
#  'stac_extensions': ['https://stac-extensions.github.io/scientific/v1.0.0/schema.json']}

# %% [markdown]
# ## Select an Item
#
# Collections have items associated with them that are used to catalog assets (labels or source imagery) for that collection. Collections vary greatly in the number of items associated with them; some may contain only a handful of items, while others may contain hundreds of thousands of items.
#
# The following cell uses the `client.list_collection_items` to get the first item in the `ref_african_crops_kenya_01_labels` collection. The `client.list_collection_items` is a Python generator that yields a dictionary for each item in the collection (you can read more about how to use Python generators [here](https://realpython.com/introduction-to-python-generators/)).

# %%
# NOTE: Here we are using using the "id" property of the collection that we fetched above as the collection_id 
#  argument to the list_collection_items function
items_iterator = client.list_collection_items(kenya_crops_labels['id'])

# Get the first item
first_item = next(items_iterator)
first_item
# Out:
# {'id': 'ref_african_crops_kenya_01_labels_02',
#  'bbox': [34.2942892760038,
#   0.5970683661706289,
#   34.3714943155646,
#   0.7144217206851109],
#  'type': 'Feature',
#  'links': [{'rel': 'collection',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_labels'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_labels'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/'},
#   {'rel': 'self',
#    'type': 'application/geo+json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_labels/items/ref_african_crops_kenya_01_labels_02'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180412',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180417',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180422',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180427',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180502',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180507',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180512',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180517',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180522',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180527',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180601',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180606',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180611',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180616',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180621',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180626',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180701',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180706',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180711',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180716',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180721',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180726',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180731',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180805',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180810',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180815',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180820',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180825',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180830',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180904',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180909',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180914',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180919',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180924',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180929',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181004',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181009',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181014',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181019',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181024',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181029',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181103',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181108',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181113',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181118',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181123',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181128',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181203',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181208',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181213',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181218',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181223',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20181228',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190102',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190107',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190112',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190117',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190122',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190127',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190201',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190206',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190211',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190216',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190221',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190226',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190303',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190308',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190313',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190318',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190323',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190328',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190402',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190407',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190412',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190417',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190422',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190427',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190502',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190507',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190512',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190517',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190522',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190527',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190601',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190606',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190611',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190616',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190621',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190626',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190701',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190706',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190711',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190716',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190721',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190726',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190731',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190805',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190810',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190815',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190820',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190825',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190830',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190904',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190909',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190914',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190919',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190924',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20190929',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191004',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191009',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191014',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191019',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191024',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191029',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191103',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191108',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191113',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191118',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191123',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191128',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191203',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191208',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191213',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191218',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191223',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20191228',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200102',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200107',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200112',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200117',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200122',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200127',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200201',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200206',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200211',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200216',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200221',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200226',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200302',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200307',
#    'type': 'application/json'},
#   {'rel': 'source',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20200312',
#    'type': 'application/json'}],
#  'assets': {'vector_labels': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wYlErDdZVZ9zuRcohGn_RXYNMOVwOZwPRDTuKm5xeTIWNKVg3TYbWuiwdW_tBtjaYz7h7ZoWeAqss71ygQWc57Rzl7EY0D-IxXgIa7sHxSpyYB7viRz7UN3rGe3CdNPi6sR2fBKKvUTHaP9qOuym3Pq9POj1bPC6Ngb_ECySlmNYNmmmCPx_KjJL8VrQEO6h_S72vznvPirJhvI19TSPmbUX3z4g_1SaF5fb44rMlrrzwBYwKkeHbAijDwbnyonay_lBRJYBTogv3TshXLm8QTPsJyAFGICxhIbv3QBHQ5wqU=',
#    'type': 'image/tiff',
#    'roles': ['data', 'labels'],
#    'title': 'Crop Labels',
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[34.3714943155646, 0.5970683661706289],
#     [34.3714943155646, 0.7144217206851109],
#     [34.2942892760038, 0.7144217206851109],
#     [34.2942892760038, 0.5970683661706289],
#     [34.3714943155646, 0.5970683661706289]]]},
#  'collection': 'ref_african_crops_kenya_01_labels',
#  'properties': {'datetime': '2018-07-01T00:00:00Z',
#   'label:type': 'vector',
#   'label:tasks': ['classification'],
#   'label:classes': [{'name': 'Water Resource', 'classes': ['rainfed']},
#    {'name': 'Crop1',
#     'classes': ['Bean',
#      'Cabbage',
#      'Cassava',
#      'Fallowland',
#      'Groundnut',
#      'Maize',
#      'Millet',
#      'Sorghum']},
#    {'name': 'Crop2',
#     'classes': ['', 'Bean', 'Cassava', 'Fallowland', 'Groundnut', 'Soybean']},
#    {'name': 'Crop3', 'classes': ['', 'Cassava']},
#    {'name': 'Crop4', 'classes': ['', 'Bean', 'Sweetpotato']},
#    {'name': 'Crop5', 'classes': ['']},
#    {'name': 'Variety',
#     'classes': ['DK 777',
#      'DK, WS 505',
#      'Hybrid 513',
#      'Local',
#      'Null',
#      'WS 403',
#      'WS 505',
#      'WS 505, Duma 403',
#      'WS 505, WS 513',
#      'WS 509',
#      'WS 513',
#      'WS 516']}],
#   'label:methods': ['manual'],
#   'label:overviews': [{'counts': [{'name': 'rainfed', 'count': 93}],
#     'property_key': 'Water Resource'},
#    {'counts': [{'name': 'Bean', 'count': 1},
#      {'name': 'Cabbage', 'count': 1},
#      {'name': 'Cassava', 'count': 20},
#      {'name': 'Fallowland', 'count': 6},
#      {'name': 'Groundnut', 'count': 3},
#      {'name': 'Maize', 'count': 59},
#      {'name': 'Millet', 'count': 2},
#      {'name': 'Sorghum', 'count': 1}],
#     'property_key': 'Crop1'},
#    {'counts': [{'name': '', 'count': 75},
#      {'name': 'Bean', 'count': 8},
#      {'name': 'Cassava', 'count': 1},
#      {'name': 'Fallowland', 'count': 2},
#      {'name': 'Groundnut', 'count': 4},
#      {'name': 'Soybean', 'count': 3}],
#     'property_key': 'Crop2'},
#    {'counts': [{'name': '', 'count': 88}, {'name': 'Cassava', 'count': 5}],
#     'property_key': 'Crop3'},
#    {'counts': [{'name': '', 'count': 89},
#      {'name': 'Bean', 'count': 3},
#      {'name': 'Sweetpotato', 'count': 1}],
#     'property_key': 'Crop4'},
#    {'counts': [{'name': '', 'count': 93}], 'property_key': 'Crop5'},
#    {'counts': [{'name': 'DK 777', 'count': 2},
#      {'name': 'DK, WS 505', 'count': 1},
#      {'name': 'Hybrid 513', 'count': 2},
#      {'name': 'Local', 'count': 1},
#      {'name': 'Null', 'count': 50},
#      {'name': 'WS 403', 'count': 2},
#      {'name': 'WS 505', 'count': 28},
#      {'name': 'WS 505, Duma 403', 'count': 1},
#      {'name': 'WS 505, WS 513', 'count': 1},
#      {'name': 'WS 509', 'count': 1},
#      {'name': 'WS 513', 'count': 3},
#      {'name': 'WS 516', 'count': 1}],
#     'property_key': 'Variety'},
#    {'statistics': [{'name': 'mean', 'value': 3.7692903225806456},
#      {'name': 'median', 'value': 4.288},
#      {'name': 'std', 'value': 0.5386247096449551},
#      {'name': 'min', 'value': 3.216},
#      {'name': 'max', 'value': 4.288}],
#     'property_key': 'Accuracy'},
#    {'statistics': [{'name': 'mean', 'value': 43.494623655913976},
#      {'name': 'median', 'value': 40.0},
#      {'name': 'std', 'value': 24.067217309892897},
#      {'name': 'min', 'value': 10.0},
#      {'name': 'max', 'value': 100.0}],
#     'property_key': 'Crop Density'},
#    {'statistics': [{'name': 'mean', 'value': 0.07526881720430108},
#      {'name': 'median', 'value': 0.0},
#      {'name': 'std', 'value': 0.6296403241704043},
#      {'name': 'min', 'value': 0.0},
#      {'name': 'max', 'value': 6.0}],
#     'property_key': 'CMD Rating'},
#    {'statistics': [{'name': 'mean', 'value': 0.1827956989247312},
#      {'name': 'median', 'value': 0.0},
#      {'name': 'std', 'value': 1.1320070340765074},
#      {'name': 'min', 'value': 0.0},
#      {'name': 'max', 'value': 9.0}],
#     'property_key': 'CBSD Rating'},
#    {'statistics': [{'name': 'mean', 'value': 0.3010752688172043},
#      {'name': 'median', 'value': 0.0},
#      {'name': 'std', 'value': 1.6667134168291324},
#      {'name': 'min', 'value': 0.0},
#      {'name': 'max', 'value': 10.0}],
#     'property_key': 'CGM Rating'},
#    {'statistics': [{'name': 'mean', 'value': 2.0},
#      {'name': 'median', 'value': 0.0},
#      {'name': 'std', 'value': 3.243723035407737},
#      {'name': 'min', 'value': 0.0},
#      {'name': 'max', 'value': 10.0}],
#     'property_key': 'Disease Rating'}],
#   'label:properties': ['Water Resource',
#    'Crop1',
#    'Crop2',
#    'Crop3',
#    'Crop4',
#    'Crop5',
#    'Variety',
#    'Accuracy',
#    'Crop Density',
#    'CMD Rating',
#    'CBSD Rating',
#    'CGM Rating',
#    'Disease Rating'],
#   'label:description': 'Kenya Tile 02 Labels'},
#  'stac_version': '1.0.0',
#  'stac_extensions': ['https://stac-extensions.github.io/storage/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/label/v1.0.1/schema.json']}

# %% [markdown]
# > **IMPORTANT:** Some collections may have hundreds of thousands of items (e.g. `bigearthnet_v1_source`). Looping over all of the items for these massive collections may take a very long time (perhaps on the order of hours), and is not recommended. To prevent accidentally looping over all assets, the `client.list_collection_items` function limits the total number of returned items to ``100`` by default. You can change this limit using the `limit` argument:
# > ```python
# > client.list_collection_items(collection['id'], limit=150)
# > ```
# > If you would like to download all of the assets associated with a collection, it is far more efficient to use the `client.download_archive` method.

# %% [markdown]
# ### List Available Assets
#
# Each STAC Item has assets associated with it, representing the actual source imagery or labels described by that Item.
#
# The cell below summarizes the assets for the first item that we selected above by printing the key within the `assets` dictionary, the asset title and the media type.

# %%
for asset_key, asset in first_item['assets'].items():
    title = asset['title']
    media_type = asset['type']
    print(f'{asset_key}: {title} [{media_type}]')
# Out:
# vector_labels: Crop Labels [image/tiff]

# %% [markdown]
# ## Download Assets
#
# To download these assets, we will first set up a helper function to get the download link from the asset and then download the content to a local file.
#
# > **NOTE:** If you are running these notebooks using Binder these resources will be downloaded to the remote file system that the notebooks are running on and **not to your local file system.** If you want to download the files to your machine, you will need to clone the repo and run the notebook locally.

# %%
import urllib.parse
from pathlib import Path
import requests


def download(item, asset_key, output_dir='.'):
    # Try to get the given asset and return None if it does not exist
    asset = item.get('assets', {}).get(asset_key)
    if asset is None:
        print(f'Asset "{asset_key}" does not exist in this item')
        return None
    
    # Try to get the download URL from the asset and return None if it does not exist
    download_url = asset.get('href')
    if download_url is None:
        print(f'Asset {asset_key} does not have an "href" property, cannot download.')
        return None
    
    session = get_session()
    r = session.get(download_url, allow_redirects=True, stream=True)
    
    filename = urllib.parse.urlsplit(r.url).path.split('/')[-1]
    output_path = Path(output_dir) / filename

    
    with output_path.open('wb') as dst:
        for chunk in r.iter_content(chunk_size=512 * 1024):
            if chunk:
                dst.write(chunk)
    
    print(f'Downloaded to {output_path.resolve()}')

# %% [markdown]
# ### Download Labels
#
#
# We can download the `labels` asset of the `selected_item` by calling the following function:

# %%
download(first_item, 'labels')
# Out:
# Asset "labels" does not exist in this item

# %% [markdown]
# ### Download Metadata
#
# Likewise, we can download the documentation pdf and property description csv.

# %%
download(first_item, 'documentation')
download(first_item, 'property_descriptions')
# Out:
# Asset "documentation" does not exist in this item
# Asset "property_descriptions" does not exist in this item

# %% [markdown]
# ### Download Source Imagery
#
# The Item that we fetched earlier represents a collection of labels. This item also contains references to all of the source imagery used to generate these labels in its `links` property. Any source imagery links will have a `rel` type of `"source"`.
#
# In the cell below we get a list of all the sources associated with this item and fetch the first one

# %%
source_links = [link for link in first_item['links'] if link['rel'] == 'source']
print(f'Number of Source Items: {len(source_links)}')

session = get_session()
r = session.get(source_links[0]['href'])
source_item = r.json()
print('First Item\n--------')
source_item
# Out:
# Number of Source Items: 141
# First Item
# --------
# {'id': 'ref_african_crops_kenya_01_source_02_20180412',
#  'bbox': [34.2942892760038,
#   0.5970683661706289,
#   34.3714943155646,
#   0.7144217206851109],
#  'type': 'Feature',
#  'links': [{'rel': 'collection',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source'},
#   {'rel': 'parent',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source'},
#   {'rel': 'root',
#    'type': 'application/json',
#    'href': 'https://api.radiant.earth/mlhub/v1/'},
#   {'rel': 'self',
#    'type': 'application/geo+json',
#    'href': 'https://api.radiant.earth/mlhub/v1/collections/ref_african_crops_kenya_01_source/items/ref_african_crops_kenya_01_source_02_20180412'}],
#  'assets': {'B01': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZvk6TqszZ47fcWI8tF0AMfxxtFs3Yf8QCkv_zoAYKFqRFiMf_lVS-KBZDvBFAXFou7Y263waeLLptLeGo75YFVnJAewmRl75xDLbAH28eA-6UkfcXTA69XW7UhHqQFjK5TKhkAUyPiq2tgVDZw1zc7AW6pyBFbBCnDcE4uLt9AeOhc8ReTB3Sn67Z26pisQCwAd0zHMuAdlhgeu6bdER5sl6GHnVEl3Uuie7fBFwzMlswsif_NobI7ISEayYD-iIeAKttU-82JdexRS3cBjxWQ9wIpff1WhhxelJ34XC8rE_HuGqTSdPmgkdB1bAvZV2p3gaInxLZP_J3u1rhKS3oJA==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B01',
#    'eo:bands': [{'name': 'B01',
#      'common_name': 'coastal',
#      'description': 'Coastal Aerosol (0.400-0.450µm)',
#      'center_wavelength': 0.443}],
#    'raster:bands': [{'name': 'coastal',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B02': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZEQUau96_Uu2V_nqI0vZz1E0MOKlAEn92IoWLRh1bcx8Sf2lUc0_nt9ckrm4zOEgHgeyDMskVfajdFT7B2UAO0zfPVqmmGg8NGk9iF4KfkMpixmjdmlsl7mFEqmvu_TDCfhPeFaHI91MOgLKNEOn9Ec7XXAfsSXIV-hP2A5ABpp6Vtki0czPN7H7KMslg19O3VJLzJMv11ePG1x3yzzUFP39HNnWRgn0SJgM5DIGAC3J3vB7Dsp8OYC8erH6pWH0gvT-lfuiFP5FwlVnv5s_hTxAXfGjv3iNeb2ueCblOm7kICExAIh_IcW9nV0drranddXoc5fsxWTQh6-GxAiMkwQ==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B02',
#    'eo:bands': [{'name': 'B02',
#      'common_name': 'blue',
#      'description': 'Blue (0.450-0.500µm)',
#      'center_wavelength': 0.492}],
#    'raster:bands': [{'name': 'blue',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B03': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZgl_wgHp7FBe-id7I_PouWO4crn72JKuagGgm4x4l_1UGH-T-1Unl0jTYSOmdI_FQq4wkEquE9GACJu70KyY6vUEM_8mJFQzU-hyRRuwvKEwJPFUECwOD1Ks5ESiXUzVs959KeUjxT7EFtoGKLxM_YUbejgBItnStttku5YUaqCmYKPbgkodF5EQmqgw3lRXVkyQSQqXg-FPUYdMxvEJ0nJfOAdAHm0QJs4onOon-uk7CZa_uFwIbYol5-a2NOmwxZTHGQbFiqIGNQGUwQ1aLqxill2bJALl6hBFmwmV5Xn0NGTS5sTXzw4lRrhPAA8mEWVFF4Cjl7Y8sfKmSB206TQ==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B03',
#    'eo:bands': [{'name': 'B03',
#      'common_name': 'green',
#      'description': 'Green (0.500-0.600µm)',
#      'center_wavelength': 0.56}],
#    'raster:bands': [{'name': 'green',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B04': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZFNP-oJHzcKz4_zOTpJ1DH6nHBuvaljzMXdEdqhkmB8olupfxwh9_YXXw7FJuEeHyN24GQhh4KPu5LcQ5T0O6vQJUVNiotzjaiesoahME3BDj_-M34xm1RUWf1qQ9zremXEPbTq8od66W3l5IE-bFCFUf51-JQEFESWzZ6G4Kdx-brnT6g4T6hu4XTvRwep50mpOoyx6hKuJi_55N2xskrJCx9fztj12XOuImWXrmmiknJ5UvSi1nkJR_1Yvf1eOutKuDS3nWUtNI9txfu419sKvBgA5zksG3eJVnFHAcOLlEvHu2WBJo4JlfUEN67mcebu5wztL77f-ROY7dC4qYUg==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B04',
#    'eo:bands': [{'name': 'B04',
#      'common_name': 'red',
#      'description': 'Red (0.600-0.700µm)',
#      'center_wavelength': 0.665}],
#    'raster:bands': [{'name': 'red',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B05': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZp6-Ie-xGmHRbliGQze1Q30LNgQPk5R0UxVy1LHLjwZKBQt_j6WY5su44IlBUxN99Lq-H3rmPJ0RbWV-BWqsYqaAQQkWIDOiLCcivQNXFthc5-IEEs2MxrpHc5qVaVNwQcedrM23w8TnpntOCWytSaTg5-Y8EbtyrVy1lllTuGGTzbdYJsgB39V-BGwtj1NPGZEHTn_YQBW0bSFD28HbSZkt1LS_qCBI_qIbuBXofQbDpLD6af_YIP6X1qsRD6pZ-mZdQMF_yUjRV2oVyckoRPt2Bz1rhIcBePN34uXptN3QPZ7f-nVq83iWE4hUHmpnb4oufGmcfeGIkP03hurvTNA==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B05',
#    'eo:bands': [{'name': 'B05',
#      'common_name': 'rededge',
#      'description': 'Vegetation Red Edge (0.700-0.790µm)',
#      'center_wavelength': 0.704}],
#    'raster:bands': [{'name': 'rededge',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B06': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZNw55QggjudAtkOf6r4xfSqq8Wpkdng93e8AlFhT2So-M7zaUXRcswqExmmSbSh2tppqoXC16-pIMrrgheMl4FBR7EOcKw88PW85L_--wVSK__HaZ30EEQNfpFuS88fB6gToE8XtlnCq5JI6FwaVFVkNLBepxU2B-r_DgSPKAljtNjt_AqTIgQ2Y6ns79d_S0z9xk1rBbh8f0bMh-iKMWhZIjQkYm5SsC2YkX1refuEY70HGCqnnaHpcc-it9fvfn8Dx_FJCHmhUVuM0ylSrUD4_ghVPkyrF8RbfO3uVdQEifeQYhiTNS5NZtN1DxzyZO_j3vUpapu0Xr6v-Ktn4sgQ==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B06',
#    'eo:bands': [{'name': 'B06',
#      'common_name': 'rededge',
#      'description': 'Vegetation Red Edge (0.700-0.790µm)',
#      'center_wavelength': 0.741}],
#    'raster:bands': [{'name': 'rededge',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B07': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZYH1GrH_0Wzi9RyLwwA2fbOYivut8ie2LfLo2V8qreTH0_atOoWBveV82VXO39QCcgHBWa4z5iK9ZObe-H-hG2KV8efK-AJjHUqMSvfAUvyKZiti6t56zRRZmr5W3bQ-sQKF8Hu_Y_YTNJ6uFBNdzApcitvsuB--fglbjQdr80PvWtFRs16k-uLsxEX9Aj521lfyGuzPfBsp9z0fL9LQ9zy3HO_Jd8ZSlYgPeBhKExgXkkxD03a52EG7W84BZvxJbBfTm4Mwc94sSxhgMVLqnSvPclAtGA1-jnck69PIqesf62pyCU3u_6upu079g9P5mYaNYNKwFOWBONiHddZQkAg==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B07',
#    'eo:bands': [{'name': 'B07',
#      'common_name': 'rededge',
#      'description': 'Vegetation Red Edge (0.700-0.790µm)',
#      'center_wavelength': 0.783}],
#    'raster:bands': [{'name': 'rededge',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B08': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZaVxrhMl9CANHww7fc5clJfojRfSLnn5dbbEtVoeqE8aE4NruH6ldZFKLcQ4TDBX_q1r8kc5BvtGQJRHFsdVB8e3GJJ6QnojaeX4oxlhDEZ5UQof0QuGNFUZxTOJQfZ1XjKs3rD_v3RbCXP4dE-LA3AgmUYQ0fe0b_reSrLzaiRxzmxhrF5U3ya8dZa4OYQcjfbmzXyTeqvOuCDo-LiSIhb40KaCvSod_2WZVDDYlU0t-zrlSXjg79-LWBftmb3PjCOatmUNBkc7Lba18xrKB-10qBiHtH0EIpxSJdgFbl45YaxWsvOwdsOgBbgUBYlCQlPpajs6SVW98-HaPsHVSlw==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B08',
#    'eo:bands': [{'name': 'B08',
#      'common_name': 'nir',
#      'description': 'Near Infrared (0.750-1.000µm)',
#      'center_wavelength': 0.833}],
#    'raster:bands': [{'name': 'nir',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B09': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZIMcHJSheQmmp_mcLPVkL2246UrMj35aYt5Hfxxu5caXkvLX608sDarjeQ0TstJ90q1ftEw_7iH-PICUZMhlaTUhWqv5sonQaYYZeJCpbXzsnYb7qaSJdYoJFU7jSEkvr3IeVACkDJGXEM_rP20h14M82NT6O_tAbN7jyPMHbqIdktpvd-ZCI6rH7GgOpREOYAhDR5j3f6nk01k7r508N_DCJAnI-KGHLBnXZxKVPQMUG2W_kXOautx2EyNXlhpu4_tXO3IzOo9K25q6PRYzoY8Gng379SVLILUEaaS-xOLrQhM-kNDHxfHJCEMDhMNmAowF82t8rzq0KxKrsE3SKTQ==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B09',
#    'eo:bands': [{'name': 'B09',
#      'common_name': 'nir09',
#      'description': 'Water Vapour (0.850-1.050µm)',
#      'center_wavelength': 0.945}],
#    'raster:bands': [{'name': 'nir09',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B11': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZ2SChM8CLeBa0chk8682dRfXPulCO7FhGkLe3CA9DJOxOyuLFFjLjeC7UKNU_-QR98665ROSY23JkAbIOXdtuNRIt7Bt3f0vxgIy7WlQq8bihC6VAHCF3_nBTgOafnN0iJsoNiHAUPCTjIe5rOANuB8jAeHoyRIVwj_5h2FK4lUGMyakkwlsRWjOPfKyz6EgJ_Qo4TVknCT6d5X0XRgmA0-CAxhNUv7EPcgorm5lTm7DtXxEnCAfmJ_P-wm0FscJlCZD5928FonOubQqxq7sBYlLMq7LgQD2MZ7q-wKX25nmpRphOY3z-BwjHcksupoiPnTGznKoVScQunPHYkaaU6g==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B11',
#    'eo:bands': [{'name': 'B11',
#      'common_name': 'swir16',
#      'description': 'Short Wavelength Infrared 1 (1.550-1.750µm)',
#      'center_wavelength': 1.614}],
#    'raster:bands': [{'name': 'swir16',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B12': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZF5l7NsSM0B8ECSSePGis0BWcdTPXSrVniQqzY0M4IbqecriyuevRekyGC20PaC6SwRegVOwrnS95YhFzip0lSkZDDIfEKLLzs0HyLHqLQV9CFGO3ykuVyxYef2yTh1u9o3ZN_aApEek01ICB3lT0MOa_hgDjYFV-eP5fhx8KY2ei63W2mD6wV5I-NBHDmorqJtZ7egLyYZzlw3VQbvbVv76ppWrR7kw4Nf6dvSv2mgx0G77yQcuXNc-PNAHf19rNkOQgE9d6f0M-TGpyE8aO1gMIx8Dml9ClpjfQVj0i2mYyHakGiverPXpzQkAF24GAu-gUFcso5OfkgKbHB0pK3A==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B12',
#    'eo:bands': [{'name': 'B12',
#      'common_name': 'swir22',
#      'description': 'Short Wavelength Infrared 2 (2.100-2.300µm)',
#      'center_wavelength': 2.202}],
#    'raster:bands': [{'name': 'swir22',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'B8A': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZz5W7kr2KgfJcfEKp69VKyxVVfoOiiKN7JmQTaoRu6g_WLdxJyjd52UreeWO6jfYfFIjDxNUV1YB6dZlkUQddWot20JHPvE1MHfM68BdlVwQNSikrlLDZh_xCq3pKXykPTa0OGn6CJlgknqhbm93wWXezb1CUSkHKoURogDjcqVAj1tTEIYe29UoLlf98tg_aIlJfCm3zbATjaSq3dc_F_hti1-mtboCL3D_LRXgXh6djZC15b-PVNhbaHkVIqotqQ4v8bzVBpCwiDGEF_IWQpfHhxRhl95G6uhkaAC-I08umMTogEVvQB47oUotcq8jZhGYsGZZJMr3HXsCl0AQnog==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data'],
#    'title': 'B8A',
#    'eo:bands': [{'name': 'B8A',
#      'common_name': 'nir08',
#      'description': 'Narrow NIR (0.750-0.900µm)',
#      'center_wavelength': 0.865}],
#    'raster:bands': [{'name': 'nir08',
#      'nodata': 'nan',
#      'data_type': 'uint16',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False},
#   'CLD': {'href': 'https://api.radiant.earth/mlhub/v1/download/gAAAAABjn1wZyjLGXGkH-m2mLcBZCgPw5ZnVNpnsJB8mlWsZ4cDA3vBMGkcy_AVtM4dIl9RHi7K5EepudGTf4fAFle_mV_n3RPVkBJm_Yu3R44xkuHX8ogDV1QgQYnrBX3IQ7dTY7JJIUpvBK1DvmtBlCaCFpDCDXhgjLEZo-rmzHOxL_jNB9DPcDX5J4LNp7EJ86kZiifLR6uBUUgidjRs_mjOyUtLagybEFDjLbXytEdujxPg4tM5LBiEbVpwuUYOCKYswNsYPYa06Vmsd3u2wU9UaHo8tStLBFGSUs_AOadApuTM9p041U5PjSSS3LJpar6Q4WemMzcSPaGLfRYPK7KTRDzutiw==',
#    'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#    'roles': ['data-mask'],
#    'title': 'CLD',
#    'raster:bands': [{'nodata': 255.0,
#      'data_type': 'uint8',
#      'spatial_resolution': 9.997558351553115}],
#    'storage:tier': 'hot',
#    'storage:region': 'westeurope',
#    'storage:platform': 'AZURE',
#    'storage:requester_pays': False}},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[34.3714943155646, 0.5970683661706289],
#     [34.3714943155646, 0.7144217206851109],
#     [34.2942892760038, 0.7144217206851109],
#     [34.2942892760038, 0.5970683661706289],
#     [34.3714943155646, 0.5970683661706289]]]},
#  'collection': 'ref_african_crops_kenya_01_source',
#  'properties': {'gsd': 10,
#   'mission': 'sentinel-2',
#   'datetime': '2018-04-12T00:00:00Z',
#   'eo:bands': [{'name': 'B01',
#     'common_name': 'coastal',
#     'description': 'Coastal Aerosol (0.400-0.450µm)',
#     'center_wavelength': 0.443},
#    {'name': 'B02',
#     'common_name': 'blue',
#     'description': 'Blue (0.450-0.500µm)',
#     'center_wavelength': 0.492},
#    {'name': 'B03',
#     'common_name': 'green',
#     'description': 'Green (0.500-0.600µm)',
#     'center_wavelength': 0.56},
#    {'name': 'B04',
#     'common_name': 'red',
#     'description': 'Red (0.600-0.700µm)',
#     'center_wavelength': 0.665},
#    {'name': 'B05',
#     'common_name': 'rededge',
#     'description': 'Vegetation Red Edge (0.700-0.790µm)',
#     'center_wavelength': 0.704},
#    {'name': 'B06',
#     'common_name': 'rededge',
#     'description': 'Vegetation Red Edge (0.700-0.790µm)',
#     'center_wavelength': 0.741},
#    {'name': 'B07',
#     'common_name': 'rededge',
#     'description': 'Vegetation Red Edge (0.700-0.790µm)',
#     'center_wavelength': 0.783},
#    {'name': 'B08',
#     'common_name': 'nir',
#     'description': 'Near Infrared (0.750-1.000µm)',
#     'center_wavelength': 0.833},
#    {'name': 'B8A',
#     'common_name': 'nir08',
#     'description': 'Narrow NIR (0.750-0.900µm)',
#     'center_wavelength': 0.865},
#    {'name': 'B09',
#     'common_name': 'nir09',
#     'description': 'Water Vapour (0.850-1.050µm)',
#     'center_wavelength': 0.945},
#    {'name': 'B11',
#     'common_name': 'swir16',
#     'description': 'Short Wavelength Infrared 1 (1.550-1.750µm)',
#     'center_wavelength': 1.614},
#    {'name': 'B12',
#     'common_name': 'swir22',
#     'description': 'Short Wavelength Infrared 2 (2.100-2.300µm)',
#     'center_wavelength': 2.202}],
#   'platform': 'Sentinel-2B',
#   'proj:epsg': 32636,
#   'proj:shape': [1348, 1065],
#   'instruments': ['msi'],
#   'constellation': 'sentinel-2',
#   'proj:transform': [9.997558351553115,
#    0.0,
#    642068.9738940755,
#    0.0,
#    -9.99944995431056,
#    79087.04207244414,
#    0.0,
#    0.0,
#    1.0]},
#  'stac_version': '1.0.0',
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/storage/v1.0.0/schema.json',
#   'https://stac-extensions.github.io/raster/v1.1.0/schema.json',
#   'https://stac-extensions.github.io/projection/v1.0.0/schema.json']}

# %% [markdown]
# Once we have the source item, we can use our `download` function to download assets associated with that item.
#
# The cell below downloads just the first 3 bands of the source item that we just fetched (a Sentinel 2 scene).

# %%
download(source_item, 'B01')
download(source_item, 'B02')
download(source_item, 'B03')
# Out:
# Downloaded to /Users/michelleroby/radiant-earth/mlhub-tutorials/notebooks/02_20180412_B01_10m.tif
# Downloaded to /Users/michelleroby/radiant-earth/mlhub-tutorials/notebooks/02_20180412_B02_10m.tif
# Downloaded to /Users/michelleroby/radiant-earth/mlhub-tutorials/notebooks/02_20180412_B03_10m.tif

# %% [markdown]
# ### Download All Assets
#
# Looping through all items and downloading the associated assets may be *very* time-consuming for larger datasets like BigEarthNet or LandCoverNet. Instead, MLHub provides TAR archives of all collections that can be downloaded using the `/archive/{collection_id}` endpoint.
#
# The following cell uses the `client.download_archive` function to download the `ref_african_crops_kenya_01_labels` archive to the current working directory.

# %%
client.download_archive('ref_african_crops_kenya_01_labels', output_dir='.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 client.download_archive('ref_african_crops_kenya_01_labels', output_dir='.')
#
# AttributeError: module 'radiant_mlhub.client' has no attribute 'download_archive'
